# %%
# !cd /content && git clone --recursive https://github.com/githubharald/CTCDecoder.git

# !cd /content/CTCDecoder && pip install .
# Out:
# Cloning into 'CTCDecoder'...
# remote: Enumerating objects: 316, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 316 (delta 12), reused 9 (delta 9), pack-reused 295
# Receiving objects: 100% (316/316), 1023.34 KiB | 7.52 MiB/s, done.
# Resolving deltas: 100% (163/163), done.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/CTCDecoder
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ctc-decoder: filename=ctc_decoder-1.0.1-py3-none-any.whl size=11848 sha256=a78b34938b576c82c9e01c0bd0495ffaeb1f930b9f2aa13953216fcabc5ccf2d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9folq5vd/wheels/60/a1/9d/e499b8ca26cce70f912ba557e981187db95eb0d66c54b8e995
# Successfully built ctc-decoder
# ...

# %% [markdown]
# # Training

# %%
# !python /content/Captcha_Recognition/train.py

# %% [markdown]
# # Load Model and make predictions

# %%
from utlis import *
from model import CaptchaModel

train_dataset, test_dataset, test_labels_orig, le = get_datasets()
test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size=16, shuffle = False)
chars = list(le.classes_)
chars = ''.join(chars)

# %%
PATH = './saved_models/model_1.pth'
model = CaptchaModel(len(le.classes_))
model.to(DEVICE)

checkpoint = torch.load(PATH)

model.load_state_dict(checkpoint['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
predict(model, test_dataloader, chars)
